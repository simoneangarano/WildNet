# %% [markdown]
# ### MobileNetV3

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import copy
import torch
from network.mobilenet_v3 import mobilenet_v3_large
from network.Resnet import resnet50
from network.utils import IntermediateLayerGetter

# %%
model_b = mobilenet_v3_large(fs_layer=[1,1,1,0,0])
# Out:
# Loading ImageNet weights...

# %%
o = model_b(torch.zeros(1,3,224,224))

# %%
o.shape
# Out:
# torch.Size([1, 1000])

# %%
model_b.features
# Out:
# Sequential(
#   (0): Conv2dNormActivation(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): AdaptiveInstanceNormalization()
#     (2): Hardswish()
#   )
#   (1): InvertedResidual(
#     (instance_norm_layer): AdaptiveInstanceNormalization()
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (2): InvertedResidual(
#     (instance_norm_layer): AdaptiveInstanceNormalization()
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (3): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (4): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#         (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (5): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (6): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (7): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (8): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#         (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (9): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#         (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (10): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#         (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (11): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (12): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#         (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (13): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (14): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#         (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (15): InvertedResidual(
#     (block): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#         (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): Hardswish()
#       )
#       (2): SqueezeExcitation(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#         (activation): ReLU()
#         (scale_activation): Hardsigmoid()
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (16): Conv2dNormActivation(
#     (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (2): Hardswish()
#   )
# )

# %%
# state_dict = model_b.state_dict()
state_dict = torch.load('weights/mobilenet_v3_large-5c1a4163.pth')
#state_dict_v2 = copy.deepcopy(state_dict)


for i in reversed(range(1,17)):
    state_dict_filt = {k: v for k, v in state_dict.items() if f'features.{i}.' in k}
    print(state_dict_filt.keys())
    for key in state_dict_filt:
        _, post = key.split(f'features.{i}.')
        state_dict[f'features.{i+1}.{post}'] = state_dict.pop(key)
        print(f'{key} \t -> features.{i+1}.{post}')
# Out:
# dict_keys(['features.16.0.weight', 'features.16.1.weight', 'features.16.1.bias', 'features.16.1.running_mean', 'features.16.1.running_var', 'features.16.1.num_batches_tracked'])
# features.16.0.weight 	 -> features.17.0.weight
# features.16.1.weight 	 -> features.17.1.weight
# features.16.1.bias 	 -> features.17.1.bias
# features.16.1.running_mean 	 -> features.17.1.running_mean
# features.16.1.running_var 	 -> features.17.1.running_var
# features.16.1.num_batches_tracked 	 -> features.17.1.num_batches_tracked
# dict_keys(['features.15.block.0.0.weight', 'features.15.block.0.1.weight', 'features.15.block.0.1.bias', 'features.15.block.0.1.running_mean', 'features.15.block.0.1.running_var', 'features.15.block.0.1.num_batches_tracked', 'features.15.block.1.0.weight', 'features.15.block.1.1.weight', 'features.15.block.1.1.bias', 'features.15.block.1.1.running_mean', 'features.15.block.1.1.running_var', 'features.15.block.1.1.num_batches_tracked', 'features.15.block.2.fc1.weight', 'features.15.block.2.fc1.bias', 'features.15.block.2.fc2.weight', 'features.15.block.2.fc2.bias', 'features.15.block.3.0.weight', 'features.15.block.3.1.weight', 'features.15.block.3.1.bias', 'features.15.block.3.1.running_mean', 'features.15.block.3.1.running_var', 'features.15.block.3.1.num_batches_tracked'])
# features.15.block.0.0.weight 	 -> features.16.block.0.0.weight
# features.15.block.0.1.weight 	 -> features.16.block.0.1.weight
# features.15.block.0.1.bias 	 -> features.16.block.0.1.bias
# features.15.block.0.1.running_mean 	 -> features.16.block.0.1.running_mean
# features.15.block.0.1.running_var 	 -> features.16.block.0.1.running_var
# features.15.block.0.1.num_batches_tracked 	 -> features.16.block.0.1.num_batches_tracked
# features.15.block.1.0.weight 	 -> features.16.block.1.0.weight
# features.15.block.1.1.weight 	 -> features.16.block.1.1.weight
# features.15.block.1.1.bias 	 -> features.16.block.1.1.bias
# features.15.block.1.1.running_mean 	 -> features.16.block.1.1.running_mean
# features.15.block.1.1.running_var 	 -> features.16.block.1.1.running_var
# features.15.block.1.1.num_batches_tracked 	 -> features.16.block.1.1.num_batches_tracked
# features.15.block.2.fc1.weight 	 -> features.16.block.2.fc1.weight
# features.15.block.2.fc1.bias 	 -> features.16.block.2.fc1.bias
# features.15.block.2.fc2.weight 	 -> features.16.block.2.fc2.weight
# features.15.block.2.fc2.bias 	 -> features.16.block.2.fc2.bias
# features.15.block.3.0.weight 	 -> features.16.block.3.0.weight
# features.15.block.3.1.weight 	 -> features.16.block.3.1.weight
# features.15.block.3.1.bias 	 -> features.16.block.3.1.bias
# features.15.block.3.1.running_mean 	 -> features.16.block.3.1.running_mean
# features.15.block.3.1.running_var 	 -> features.16.block.3.1.running_var
# features.15.block.3.1.num_batches_tracked 	 -> features.16.block.3.1.num_batches_tracked
# dict_keys(['features.14.block.0.0.weight', 'features.14.block.0.1.weight', 'features.14.block.0.1.bias', 'features.14.block.0.1.running_mean', 'features.14.block.0.1.running_var', 'features.14.block.0.1.num_batches_tracked', 'features.14.block.1.0.weight', 'features.14.block.1.1.weight', 'features.14.block.1.1.bias', 'features.14.block.1.1.running_mean', 'features.14.block.1.1.running_var', 'features.14.block.1.1.num_batches_tracked', 'features.14.block.2.fc1.weight', 'features.14.block.2.fc1.bias', 'features.14.block.2.fc2.weight', 'features.14.block.2.fc2.bias', 'features.14.block.3.0.weight', 'features.14.block.3.1.weight', 'features.14.block.3.1.bias', 'features.14.block.3.1.running_mean', 'features.14.block.3.1.running_var', 'features.14.block.3.1.num_batches_tracked'])
# features.14.block.0.0.weight 	 -> features.15.block.0.0.weight
# features.14.block.0.1.weight 	 -> features.15.block.0.1.weight
# features.14.block.0.1.bias 	 -> features.15.block.0.1.bias
# features.14.block.0.1.running_mean 	 -> features.15.block.0.1.running_mean
# features.14.block.0.1.running_var 	 -> features.15.block.0.1.running_var
# features.14.block.0.1.num_batches_tracked 	 -> features.15.block.0.1.num_batches_tracked
# features.14.block.1.0.weight 	 -> features.15.block.1.0.weight
# features.14.block.1.1.weight 	 -> features.15.block.1.1.weight
# features.14.block.1.1.bias 	 -> features.15.block.1.1.bias
# features.14.block.1.1.running_mean 	 -> features.15.block.1.1.running_mean
# features.14.block.1.1.running_var 	 -> features.15.block.1.1.running_var
# features.14.block.1.1.num_batches_tracked 	 -> features.15.block.1.1.num_batches_tracked
# features.14.block.2.fc1.weight 	 -> features.15.block.2.fc1.weight
# features.14.block.2.fc1.bias 	 -> features.15.block.2.fc1.bias
# features.14.block.2.fc2.weight 	 -> features.15.block.2.fc2.weight
# features.14.block.2.fc2.bias 	 -> features.15.block.2.fc2.bias
# features.14.block.3.0.weight 	 -> features.15.block.3.0.weight
# features.14.block.3.1.weight 	 -> features.15.block.3.1.weight
# features.14.block.3.1.bias 	 -> features.15.block.3.1.bias
# features.14.block.3.1.running_mean 	 -> features.15.block.3.1.running_mean
# features.14.block.3.1.running_var 	 -> features.15.block.3.1.running_var
# features.14.block.3.1.num_batches_tracked 	 -> features.15.block.3.1.num_batches_tracked
# dict_keys(['features.13.block.0.0.weight', 'features.13.block.0.1.weight', 'features.13.block.0.1.bias', 'features.13.block.0.1.running_mean', 'features.13.block.0.1.running_var', 'features.13.block.0.1.num_batches_tracked', 'features.13.block.1.0.weight', 'features.13.block.1.1.weight', 'features.13.block.1.1.bias', 'features.13.block.1.1.running_mean', 'features.13.block.1.1.running_var', 'features.13.block.1.1.num_batches_tracked', 'features.13.block.2.fc1.weight', 'features.13.block.2.fc1.bias', 'features.13.block.2.fc2.weight', 'features.13.block.2.fc2.bias', 'features.13.block.3.0.weight', 'features.13.block.3.1.weight', 'features.13.block.3.1.bias', 'features.13.block.3.1.running_mean', 'features.13.block.3.1.running_var', 'features.13.block.3.1.num_batches_tracked'])
# features.13.block.0.0.weight 	 -> features.14.block.0.0.weight
# features.13.block.0.1.weight 	 -> features.14.block.0.1.weight
# features.13.block.0.1.bias 	 -> features.14.block.0.1.bias
# features.13.block.0.1.running_mean 	 -> features.14.block.0.1.running_mean
# features.13.block.0.1.running_var 	 -> features.14.block.0.1.running_var
# features.13.block.0.1.num_batches_tracked 	 -> features.14.block.0.1.num_batches_tracked
# features.13.block.1.0.weight 	 -> features.14.block.1.0.weight
# features.13.block.1.1.weight 	 -> features.14.block.1.1.weight
# features.13.block.1.1.bias 	 -> features.14.block.1.1.bias
# features.13.block.1.1.running_mean 	 -> features.14.block.1.1.running_mean
# features.13.block.1.1.running_var 	 -> features.14.block.1.1.running_var
# features.13.block.1.1.num_batches_tracked 	 -> features.14.block.1.1.num_batches_tracked
# features.13.block.2.fc1.weight 	 -> features.14.block.2.fc1.weight
# features.13.block.2.fc1.bias 	 -> features.14.block.2.fc1.bias
# features.13.block.2.fc2.weight 	 -> features.14.block.2.fc2.weight
# features.13.block.2.fc2.bias 	 -> features.14.block.2.fc2.bias
# features.13.block.3.0.weight 	 -> features.14.block.3.0.weight
# features.13.block.3.1.weight 	 -> features.14.block.3.1.weight
# features.13.block.3.1.bias 	 -> features.14.block.3.1.bias
# features.13.block.3.1.running_mean 	 -> features.14.block.3.1.running_mean
# features.13.block.3.1.running_var 	 -> features.14.block.3.1.running_var
# features.13.block.3.1.num_batches_tracked 	 -> features.14.block.3.1.num_batches_tracked
# dict_keys(['features.12.block.0.0.weight', 'features.12.block.0.1.weight', 'features.12.block.0.1.bias', 'features.12.block.0.1.running_mean', 'features.12.block.0.1.running_var', 'features.12.block.0.1.num_batches_tracked', 'features.12.block.1.0.weight', 'features.12.block.1.1.weight', 'features.12.block.1.1.bias', 'features.12.block.1.1.running_mean', 'features.12.block.1.1.running_var', 'features.12.block.1.1.num_batches_tracked', 'features.12.block.2.fc1.weight', 'features.12.block.2.fc1.bias', 'features.12.block.2.fc2.weight', 'features.12.block.2.fc2.bias', 'features.12.block.3.0.weight', 'features.12.block.3.1.weight', 'features.12.block.3.1.bias', 'features.12.block.3.1.running_mean', 'features.12.block.3.1.running_var', 'features.12.block.3.1.num_batches_tracked'])
# features.12.block.0.0.weight 	 -> features.13.block.0.0.weight
# features.12.block.0.1.weight 	 -> features.13.block.0.1.weight
# features.12.block.0.1.bias 	 -> features.13.block.0.1.bias
# features.12.block.0.1.running_mean 	 -> features.13.block.0.1.running_mean
# features.12.block.0.1.running_var 	 -> features.13.block.0.1.running_var
# features.12.block.0.1.num_batches_tracked 	 -> features.13.block.0.1.num_batches_tracked
# features.12.block.1.0.weight 	 -> features.13.block.1.0.weight
# features.12.block.1.1.weight 	 -> features.13.block.1.1.weight
# features.12.block.1.1.bias 	 -> features.13.block.1.1.bias
# features.12.block.1.1.running_mean 	 -> features.13.block.1.1.running_mean
# features.12.block.1.1.running_var 	 -> features.13.block.1.1.running_var
# features.12.block.1.1.num_batches_tracked 	 -> features.13.block.1.1.num_batches_tracked
# features.12.block.2.fc1.weight 	 -> features.13.block.2.fc1.weight
# features.12.block.2.fc1.bias 	 -> features.13.block.2.fc1.bias
# features.12.block.2.fc2.weight 	 -> features.13.block.2.fc2.weight
# features.12.block.2.fc2.bias 	 -> features.13.block.2.fc2.bias
# features.12.block.3.0.weight 	 -> features.13.block.3.0.weight
# features.12.block.3.1.weight 	 -> features.13.block.3.1.weight
# features.12.block.3.1.bias 	 -> features.13.block.3.1.bias
# features.12.block.3.1.running_mean 	 -> features.13.block.3.1.running_mean
# features.12.block.3.1.running_var 	 -> features.13.block.3.1.running_var
# features.12.block.3.1.num_batches_tracked 	 -> features.13.block.3.1.num_batches_tracked
# dict_keys(['features.11.block.0.0.weight', 'features.11.block.0.1.weight', 'features.11.block.0.1.bias', 'features.11.block.0.1.running_mean', 'features.11.block.0.1.running_var', 'features.11.block.0.1.num_batches_tracked', 'features.11.block.1.0.weight', 'features.11.block.1.1.weight', 'features.11.block.1.1.bias', 'features.11.block.1.1.running_mean', 'features.11.block.1.1.running_var', 'features.11.block.1.1.num_batches_tracked', 'features.11.block.2.fc1.weight', 'features.11.block.2.fc1.bias', 'features.11.block.2.fc2.weight', 'features.11.block.2.fc2.bias', 'features.11.block.3.0.weight', 'features.11.block.3.1.weight', 'features.11.block.3.1.bias', 'features.11.block.3.1.running_mean', 'features.11.block.3.1.running_var', 'features.11.block.3.1.num_batches_tracked'])
# features.11.block.0.0.weight 	 -> features.12.block.0.0.weight
# features.11.block.0.1.weight 	 -> features.12.block.0.1.weight
# features.11.block.0.1.bias 	 -> features.12.block.0.1.bias
# features.11.block.0.1.running_mean 	 -> features.12.block.0.1.running_mean
# features.11.block.0.1.running_var 	 -> features.12.block.0.1.running_var
# features.11.block.0.1.num_batches_tracked 	 -> features.12.block.0.1.num_batches_tracked
# features.11.block.1.0.weight 	 -> features.12.block.1.0.weight
# features.11.block.1.1.weight 	 -> features.12.block.1.1.weight
# features.11.block.1.1.bias 	 -> features.12.block.1.1.bias
# features.11.block.1.1.running_mean 	 -> features.12.block.1.1.running_mean
# features.11.block.1.1.running_var 	 -> features.12.block.1.1.running_var
# features.11.block.1.1.num_batches_tracked 	 -> features.12.block.1.1.num_batches_tracked
# features.11.block.2.fc1.weight 	 -> features.12.block.2.fc1.weight
# features.11.block.2.fc1.bias 	 -> features.12.block.2.fc1.bias
# features.11.block.2.fc2.weight 	 -> features.12.block.2.fc2.weight
# features.11.block.2.fc2.bias 	 -> features.12.block.2.fc2.bias
# features.11.block.3.0.weight 	 -> features.12.block.3.0.weight
# features.11.block.3.1.weight 	 -> features.12.block.3.1.weight
# features.11.block.3.1.bias 	 -> features.12.block.3.1.bias
# features.11.block.3.1.running_mean 	 -> features.12.block.3.1.running_mean
# features.11.block.3.1.running_var 	 -> features.12.block.3.1.running_var
# features.11.block.3.1.num_batches_tracked 	 -> features.12.block.3.1.num_batches_tracked
# dict_keys(['features.10.block.0.0.weight', 'features.10.block.0.1.weight', 'features.10.block.0.1.bias', 'features.10.block.0.1.running_mean', 'features.10.block.0.1.running_var', 'features.10.block.0.1.num_batches_tracked', 'features.10.block.1.0.weight', 'features.10.block.1.1.weight', 'features.10.block.1.1.bias', 'features.10.block.1.1.running_mean', 'features.10.block.1.1.running_var', 'features.10.block.1.1.num_batches_tracked', 'features.10.block.2.0.weight', 'features.10.block.2.1.weight', 'features.10.block.2.1.bias', 'features.10.block.2.1.running_mean', 'features.10.block.2.1.running_var', 'features.10.block.2.1.num_batches_tracked'])
# features.10.block.0.0.weight 	 -> features.11.block.0.0.weight
# features.10.block.0.1.weight 	 -> features.11.block.0.1.weight
# features.10.block.0.1.bias 	 -> features.11.block.0.1.bias
# features.10.block.0.1.running_mean 	 -> features.11.block.0.1.running_mean
# features.10.block.0.1.running_var 	 -> features.11.block.0.1.running_var
# features.10.block.0.1.num_batches_tracked 	 -> features.11.block.0.1.num_batches_tracked
# features.10.block.1.0.weight 	 -> features.11.block.1.0.weight
# features.10.block.1.1.weight 	 -> features.11.block.1.1.weight
# features.10.block.1.1.bias 	 -> features.11.block.1.1.bias
# features.10.block.1.1.running_mean 	 -> features.11.block.1.1.running_mean
# features.10.block.1.1.running_var 	 -> features.11.block.1.1.running_var
# features.10.block.1.1.num_batches_tracked 	 -> features.11.block.1.1.num_batches_tracked
# features.10.block.2.0.weight 	 -> features.11.block.2.0.weight
# features.10.block.2.1.weight 	 -> features.11.block.2.1.weight
# features.10.block.2.1.bias 	 -> features.11.block.2.1.bias
# features.10.block.2.1.running_mean 	 -> features.11.block.2.1.running_mean
# features.10.block.2.1.running_var 	 -> features.11.block.2.1.running_var
# features.10.block.2.1.num_batches_tracked 	 -> features.11.block.2.1.num_batches_tracked
# dict_keys(['features.9.block.0.0.weight', 'features.9.block.0.1.weight', 'features.9.block.0.1.bias', 'features.9.block.0.1.running_mean', 'features.9.block.0.1.running_var', 'features.9.block.0.1.num_batches_tracked', 'features.9.block.1.0.weight', 'features.9.block.1.1.weight', 'features.9.block.1.1.bias', 'features.9.block.1.1.running_mean', 'features.9.block.1.1.running_var', 'features.9.block.1.1.num_batches_tracked', 'features.9.block.2.0.weight', 'features.9.block.2.1.weight', 'features.9.block.2.1.bias', 'features.9.block.2.1.running_mean', 'features.9.block.2.1.running_var', 'features.9.block.2.1.num_batches_tracked'])
# features.9.block.0.0.weight 	 -> features.10.block.0.0.weight
# features.9.block.0.1.weight 	 -> features.10.block.0.1.weight
# features.9.block.0.1.bias 	 -> features.10.block.0.1.bias
# features.9.block.0.1.running_mean 	 -> features.10.block.0.1.running_mean
# features.9.block.0.1.running_var 	 -> features.10.block.0.1.running_var
# features.9.block.0.1.num_batches_tracked 	 -> features.10.block.0.1.num_batches_tracked
# features.9.block.1.0.weight 	 -> features.10.block.1.0.weight
# features.9.block.1.1.weight 	 -> features.10.block.1.1.weight
# features.9.block.1.1.bias 	 -> features.10.block.1.1.bias
# features.9.block.1.1.running_mean 	 -> features.10.block.1.1.running_mean
# features.9.block.1.1.running_var 	 -> features.10.block.1.1.running_var
# features.9.block.1.1.num_batches_tracked 	 -> features.10.block.1.1.num_batches_tracked
# features.9.block.2.0.weight 	 -> features.10.block.2.0.weight
# features.9.block.2.1.weight 	 -> features.10.block.2.1.weight
# features.9.block.2.1.bias 	 -> features.10.block.2.1.bias
# features.9.block.2.1.running_mean 	 -> features.10.block.2.1.running_mean
# features.9.block.2.1.running_var 	 -> features.10.block.2.1.running_var
# features.9.block.2.1.num_batches_tracked 	 -> features.10.block.2.1.num_batches_tracked
# dict_keys(['features.8.block.0.0.weight', 'features.8.block.0.1.weight', 'features.8.block.0.1.bias', 'features.8.block.0.1.running_mean', 'features.8.block.0.1.running_var', 'features.8.block.0.1.num_batches_tracked', 'features.8.block.1.0.weight', 'features.8.block.1.1.weight', 'features.8.block.1.1.bias', 'features.8.block.1.1.running_mean', 'features.8.block.1.1.running_var', 'features.8.block.1.1.num_batches_tracked', 'features.8.block.2.0.weight', 'features.8.block.2.1.weight', 'features.8.block.2.1.bias', 'features.8.block.2.1.running_mean', 'features.8.block.2.1.running_var', 'features.8.block.2.1.num_batches_tracked'])
# features.8.block.0.0.weight 	 -> features.9.block.0.0.weight
# features.8.block.0.1.weight 	 -> features.9.block.0.1.weight
# features.8.block.0.1.bias 	 -> features.9.block.0.1.bias
# features.8.block.0.1.running_mean 	 -> features.9.block.0.1.running_mean
# features.8.block.0.1.running_var 	 -> features.9.block.0.1.running_var
# features.8.block.0.1.num_batches_tracked 	 -> features.9.block.0.1.num_batches_tracked
# features.8.block.1.0.weight 	 -> features.9.block.1.0.weight
# features.8.block.1.1.weight 	 -> features.9.block.1.1.weight
# features.8.block.1.1.bias 	 -> features.9.block.1.1.bias
# features.8.block.1.1.running_mean 	 -> features.9.block.1.1.running_mean
# features.8.block.1.1.running_var 	 -> features.9.block.1.1.running_var
# features.8.block.1.1.num_batches_tracked 	 -> features.9.block.1.1.num_batches_tracked
# features.8.block.2.0.weight 	 -> features.9.block.2.0.weight
# features.8.block.2.1.weight 	 -> features.9.block.2.1.weight
# features.8.block.2.1.bias 	 -> features.9.block.2.1.bias
# features.8.block.2.1.running_mean 	 -> features.9.block.2.1.running_mean
# features.8.block.2.1.running_var 	 -> features.9.block.2.1.running_var
# features.8.block.2.1.num_batches_tracked 	 -> features.9.block.2.1.num_batches_tracked
# dict_keys(['features.7.block.0.0.weight', 'features.7.block.0.1.weight', 'features.7.block.0.1.bias', 'features.7.block.0.1.running_mean', 'features.7.block.0.1.running_var', 'features.7.block.0.1.num_batches_tracked', 'features.7.block.1.0.weight', 'features.7.block.1.1.weight', 'features.7.block.1.1.bias', 'features.7.block.1.1.running_mean', 'features.7.block.1.1.running_var', 'features.7.block.1.1.num_batches_tracked', 'features.7.block.2.0.weight', 'features.7.block.2.1.weight', 'features.7.block.2.1.bias', 'features.7.block.2.1.running_mean', 'features.7.block.2.1.running_var', 'features.7.block.2.1.num_batches_tracked'])
# features.7.block.0.0.weight 	 -> features.8.block.0.0.weight
# features.7.block.0.1.weight 	 -> features.8.block.0.1.weight
# features.7.block.0.1.bias 	 -> features.8.block.0.1.bias
# features.7.block.0.1.running_mean 	 -> features.8.block.0.1.running_mean
# features.7.block.0.1.running_var 	 -> features.8.block.0.1.running_var
# features.7.block.0.1.num_batches_tracked 	 -> features.8.block.0.1.num_batches_tracked
# features.7.block.1.0.weight 	 -> features.8.block.1.0.weight
# features.7.block.1.1.weight 	 -> features.8.block.1.1.weight
# features.7.block.1.1.bias 	 -> features.8.block.1.1.bias
# features.7.block.1.1.running_mean 	 -> features.8.block.1.1.running_mean
# features.7.block.1.1.running_var 	 -> features.8.block.1.1.running_var
# features.7.block.1.1.num_batches_tracked 	 -> features.8.block.1.1.num_batches_tracked
# features.7.block.2.0.weight 	 -> features.8.block.2.0.weight
# features.7.block.2.1.weight 	 -> features.8.block.2.1.weight
# features.7.block.2.1.bias 	 -> features.8.block.2.1.bias
# features.7.block.2.1.running_mean 	 -> features.8.block.2.1.running_mean
# features.7.block.2.1.running_var 	 -> features.8.block.2.1.running_var
# features.7.block.2.1.num_batches_tracked 	 -> features.8.block.2.1.num_batches_tracked
# dict_keys(['features.6.block.0.0.weight', 'features.6.block.0.1.weight', 'features.6.block.0.1.bias', 'features.6.block.0.1.running_mean', 'features.6.block.0.1.running_var', 'features.6.block.0.1.num_batches_tracked', 'features.6.block.1.0.weight', 'features.6.block.1.1.weight', 'features.6.block.1.1.bias', 'features.6.block.1.1.running_mean', 'features.6.block.1.1.running_var', 'features.6.block.1.1.num_batches_tracked', 'features.6.block.2.fc1.weight', 'features.6.block.2.fc1.bias', 'features.6.block.2.fc2.weight', 'features.6.block.2.fc2.bias', 'features.6.block.3.0.weight', 'features.6.block.3.1.weight', 'features.6.block.3.1.bias', 'features.6.block.3.1.running_mean', 'features.6.block.3.1.running_var', 'features.6.block.3.1.num_batches_tracked'])
# features.6.block.0.0.weight 	 -> features.7.block.0.0.weight
# features.6.block.0.1.weight 	 -> features.7.block.0.1.weight
# features.6.block.0.1.bias 	 -> features.7.block.0.1.bias
# features.6.block.0.1.running_mean 	 -> features.7.block.0.1.running_mean
# features.6.block.0.1.running_var 	 -> features.7.block.0.1.running_var
# features.6.block.0.1.num_batches_tracked 	 -> features.7.block.0.1.num_batches_tracked
# features.6.block.1.0.weight 	 -> features.7.block.1.0.weight
# features.6.block.1.1.weight 	 -> features.7.block.1.1.weight
# features.6.block.1.1.bias 	 -> features.7.block.1.1.bias
# features.6.block.1.1.running_mean 	 -> features.7.block.1.1.running_mean
# features.6.block.1.1.running_var 	 -> features.7.block.1.1.running_var
# features.6.block.1.1.num_batches_tracked 	 -> features.7.block.1.1.num_batches_tracked
# features.6.block.2.fc1.weight 	 -> features.7.block.2.fc1.weight
# features.6.block.2.fc1.bias 	 -> features.7.block.2.fc1.bias
# features.6.block.2.fc2.weight 	 -> features.7.block.2.fc2.weight
# features.6.block.2.fc2.bias 	 -> features.7.block.2.fc2.bias
# features.6.block.3.0.weight 	 -> features.7.block.3.0.weight
# features.6.block.3.1.weight 	 -> features.7.block.3.1.weight
# features.6.block.3.1.bias 	 -> features.7.block.3.1.bias
# features.6.block.3.1.running_mean 	 -> features.7.block.3.1.running_mean
# features.6.block.3.1.running_var 	 -> features.7.block.3.1.running_var
# features.6.block.3.1.num_batches_tracked 	 -> features.7.block.3.1.num_batches_tracked
# dict_keys(['features.5.block.0.0.weight', 'features.5.block.0.1.weight', 'features.5.block.0.1.bias', 'features.5.block.0.1.running_mean', 'features.5.block.0.1.running_var', 'features.5.block.0.1.num_batches_tracked', 'features.5.block.1.0.weight', 'features.5.block.1.1.weight', 'features.5.block.1.1.bias', 'features.5.block.1.1.running_mean', 'features.5.block.1.1.running_var', 'features.5.block.1.1.num_batches_tracked', 'features.5.block.2.fc1.weight', 'features.5.block.2.fc1.bias', 'features.5.block.2.fc2.weight', 'features.5.block.2.fc2.bias', 'features.5.block.3.0.weight', 'features.5.block.3.1.weight', 'features.5.block.3.1.bias', 'features.5.block.3.1.running_mean', 'features.5.block.3.1.running_var', 'features.5.block.3.1.num_batches_tracked'])
# features.5.block.0.0.weight 	 -> features.6.block.0.0.weight
# features.5.block.0.1.weight 	 -> features.6.block.0.1.weight
# features.5.block.0.1.bias 	 -> features.6.block.0.1.bias
# features.5.block.0.1.running_mean 	 -> features.6.block.0.1.running_mean
# features.5.block.0.1.running_var 	 -> features.6.block.0.1.running_var
# features.5.block.0.1.num_batches_tracked 	 -> features.6.block.0.1.num_batches_tracked
# features.5.block.1.0.weight 	 -> features.6.block.1.0.weight
# features.5.block.1.1.weight 	 -> features.6.block.1.1.weight
# features.5.block.1.1.bias 	 -> features.6.block.1.1.bias
# features.5.block.1.1.running_mean 	 -> features.6.block.1.1.running_mean
# features.5.block.1.1.running_var 	 -> features.6.block.1.1.running_var
# features.5.block.1.1.num_batches_tracked 	 -> features.6.block.1.1.num_batches_tracked
# features.5.block.2.fc1.weight 	 -> features.6.block.2.fc1.weight
# features.5.block.2.fc1.bias 	 -> features.6.block.2.fc1.bias
# features.5.block.2.fc2.weight 	 -> features.6.block.2.fc2.weight
# features.5.block.2.fc2.bias 	 -> features.6.block.2.fc2.bias
# features.5.block.3.0.weight 	 -> features.6.block.3.0.weight
# features.5.block.3.1.weight 	 -> features.6.block.3.1.weight
# features.5.block.3.1.bias 	 -> features.6.block.3.1.bias
# features.5.block.3.1.running_mean 	 -> features.6.block.3.1.running_mean
# features.5.block.3.1.running_var 	 -> features.6.block.3.1.running_var
# features.5.block.3.1.num_batches_tracked 	 -> features.6.block.3.1.num_batches_tracked
# dict_keys(['features.4.block.0.0.weight', 'features.4.block.0.1.weight', 'features.4.block.0.1.bias', 'features.4.block.0.1.running_mean', 'features.4.block.0.1.running_var', 'features.4.block.0.1.num_batches_tracked', 'features.4.block.1.0.weight', 'features.4.block.1.1.weight', 'features.4.block.1.1.bias', 'features.4.block.1.1.running_mean', 'features.4.block.1.1.running_var', 'features.4.block.1.1.num_batches_tracked', 'features.4.block.2.fc1.weight', 'features.4.block.2.fc1.bias', 'features.4.block.2.fc2.weight', 'features.4.block.2.fc2.bias', 'features.4.block.3.0.weight', 'features.4.block.3.1.weight', 'features.4.block.3.1.bias', 'features.4.block.3.1.running_mean', 'features.4.block.3.1.running_var', 'features.4.block.3.1.num_batches_tracked'])
# features.4.block.0.0.weight 	 -> features.5.block.0.0.weight
# features.4.block.0.1.weight 	 -> features.5.block.0.1.weight
# features.4.block.0.1.bias 	 -> features.5.block.0.1.bias
# features.4.block.0.1.running_mean 	 -> features.5.block.0.1.running_mean
# features.4.block.0.1.running_var 	 -> features.5.block.0.1.running_var
# features.4.block.0.1.num_batches_tracked 	 -> features.5.block.0.1.num_batches_tracked
# features.4.block.1.0.weight 	 -> features.5.block.1.0.weight
# features.4.block.1.1.weight 	 -> features.5.block.1.1.weight
# features.4.block.1.1.bias 	 -> features.5.block.1.1.bias
# features.4.block.1.1.running_mean 	 -> features.5.block.1.1.running_mean
# features.4.block.1.1.running_var 	 -> features.5.block.1.1.running_var
# features.4.block.1.1.num_batches_tracked 	 -> features.5.block.1.1.num_batches_tracked
# features.4.block.2.fc1.weight 	 -> features.5.block.2.fc1.weight
# features.4.block.2.fc1.bias 	 -> features.5.block.2.fc1.bias
# features.4.block.2.fc2.weight 	 -> features.5.block.2.fc2.weight
# features.4.block.2.fc2.bias 	 -> features.5.block.2.fc2.bias
# features.4.block.3.0.weight 	 -> features.5.block.3.0.weight
# features.4.block.3.1.weight 	 -> features.5.block.3.1.weight
# features.4.block.3.1.bias 	 -> features.5.block.3.1.bias
# features.4.block.3.1.running_mean 	 -> features.5.block.3.1.running_mean
# features.4.block.3.1.running_var 	 -> features.5.block.3.1.running_var
# features.4.block.3.1.num_batches_tracked 	 -> features.5.block.3.1.num_batches_tracked
# dict_keys(['features.3.block.0.0.weight', 'features.3.block.0.1.weight', 'features.3.block.0.1.bias', 'features.3.block.0.1.running_mean', 'features.3.block.0.1.running_var', 'features.3.block.0.1.num_batches_tracked', 'features.3.block.1.0.weight', 'features.3.block.1.1.weight', 'features.3.block.1.1.bias', 'features.3.block.1.1.running_mean', 'features.3.block.1.1.running_var', 'features.3.block.1.1.num_batches_tracked', 'features.3.block.2.0.weight', 'features.3.block.2.1.weight', 'features.3.block.2.1.bias', 'features.3.block.2.1.running_mean', 'features.3.block.2.1.running_var', 'features.3.block.2.1.num_batches_tracked'])
# features.3.block.0.0.weight 	 -> features.4.block.0.0.weight
# features.3.block.0.1.weight 	 -> features.4.block.0.1.weight
# features.3.block.0.1.bias 	 -> features.4.block.0.1.bias
# features.3.block.0.1.running_mean 	 -> features.4.block.0.1.running_mean
# features.3.block.0.1.running_var 	 -> features.4.block.0.1.running_var
# features.3.block.0.1.num_batches_tracked 	 -> features.4.block.0.1.num_batches_tracked
# features.3.block.1.0.weight 	 -> features.4.block.1.0.weight
# features.3.block.1.1.weight 	 -> features.4.block.1.1.weight
# features.3.block.1.1.bias 	 -> features.4.block.1.1.bias
# features.3.block.1.1.running_mean 	 -> features.4.block.1.1.running_mean
# features.3.block.1.1.running_var 	 -> features.4.block.1.1.running_var
# features.3.block.1.1.num_batches_tracked 	 -> features.4.block.1.1.num_batches_tracked
# features.3.block.2.0.weight 	 -> features.4.block.2.0.weight
# features.3.block.2.1.weight 	 -> features.4.block.2.1.weight
# features.3.block.2.1.bias 	 -> features.4.block.2.1.bias
# features.3.block.2.1.running_mean 	 -> features.4.block.2.1.running_mean
# features.3.block.2.1.running_var 	 -> features.4.block.2.1.running_var
# features.3.block.2.1.num_batches_tracked 	 -> features.4.block.2.1.num_batches_tracked
# dict_keys(['features.2.block.0.0.weight', 'features.2.block.0.1.weight', 'features.2.block.0.1.bias', 'features.2.block.0.1.running_mean', 'features.2.block.0.1.running_var', 'features.2.block.0.1.num_batches_tracked', 'features.2.block.1.0.weight', 'features.2.block.1.1.weight', 'features.2.block.1.1.bias', 'features.2.block.1.1.running_mean', 'features.2.block.1.1.running_var', 'features.2.block.1.1.num_batches_tracked', 'features.2.block.2.0.weight', 'features.2.block.2.1.weight', 'features.2.block.2.1.bias', 'features.2.block.2.1.running_mean', 'features.2.block.2.1.running_var', 'features.2.block.2.1.num_batches_tracked'])
# features.2.block.0.0.weight 	 -> features.3.block.0.0.weight
# features.2.block.0.1.weight 	 -> features.3.block.0.1.weight
# features.2.block.0.1.bias 	 -> features.3.block.0.1.bias
# features.2.block.0.1.running_mean 	 -> features.3.block.0.1.running_mean
# features.2.block.0.1.running_var 	 -> features.3.block.0.1.running_var
# features.2.block.0.1.num_batches_tracked 	 -> features.3.block.0.1.num_batches_tracked
# features.2.block.1.0.weight 	 -> features.3.block.1.0.weight
# features.2.block.1.1.weight 	 -> features.3.block.1.1.weight
# features.2.block.1.1.bias 	 -> features.3.block.1.1.bias
# features.2.block.1.1.running_mean 	 -> features.3.block.1.1.running_mean
# features.2.block.1.1.running_var 	 -> features.3.block.1.1.running_var
# features.2.block.1.1.num_batches_tracked 	 -> features.3.block.1.1.num_batches_tracked
# features.2.block.2.0.weight 	 -> features.3.block.2.0.weight
# features.2.block.2.1.weight 	 -> features.3.block.2.1.weight
# features.2.block.2.1.bias 	 -> features.3.block.2.1.bias
# features.2.block.2.1.running_mean 	 -> features.3.block.2.1.running_mean
# features.2.block.2.1.running_var 	 -> features.3.block.2.1.running_var
# features.2.block.2.1.num_batches_tracked 	 -> features.3.block.2.1.num_batches_tracked
# dict_keys(['features.1.block.0.0.weight', 'features.1.block.0.1.weight', 'features.1.block.0.1.bias', 'features.1.block.0.1.running_mean', 'features.1.block.0.1.running_var', 'features.1.block.0.1.num_batches_tracked', 'features.1.block.1.0.weight', 'features.1.block.1.1.weight', 'features.1.block.1.1.bias', 'features.1.block.1.1.running_mean', 'features.1.block.1.1.running_var', 'features.1.block.1.1.num_batches_tracked'])
# features.1.block.0.0.weight 	 -> features.2.block.0.0.weight
# features.1.block.0.1.weight 	 -> features.2.block.0.1.weight
# features.1.block.0.1.bias 	 -> features.2.block.0.1.bias
# features.1.block.0.1.running_mean 	 -> features.2.block.0.1.running_mean
# features.1.block.0.1.running_var 	 -> features.2.block.0.1.running_var
# features.1.block.0.1.num_batches_tracked 	 -> features.2.block.0.1.num_batches_tracked
# features.1.block.1.0.weight 	 -> features.2.block.1.0.weight
# features.1.block.1.1.weight 	 -> features.2.block.1.1.weight
# features.1.block.1.1.bias 	 -> features.2.block.1.1.bias
# features.1.block.1.1.running_mean 	 -> features.2.block.1.1.running_mean
# features.1.block.1.1.running_var 	 -> features.2.block.1.1.running_var
# features.1.block.1.1.num_batches_tracked 	 -> features.2.block.1.1.num_batches_tracked

# %%
backbone = model_b.features
# Gather the indices of blocks which are strided. These are the locations of C1, ..., Cn-1 blocks.
# The first and last blocks are always included because they are the C0 (conv1) and Cn.
stage_indices = [0] + [i for i, b in enumerate(backbone) if getattr(b, "_is_cn", False)] + [len(backbone) - 1]
low_pos = stage_indices[-4]  # use C2 here which has output_stride = 8
high_pos = stage_indices[-1]  # use C5 which has output_stride = 16
low_channels = backbone[low_pos].out_channels
high_channels = backbone[high_pos].out_channels
backbone = IntermediateLayerGetter(backbone, return_layers={str(low_pos): "low", str(high_pos): "high"})

# %%
backbone = model_b.features

backbone[high_pos].out_channels
# Out:
# 960

# %% [markdown]
# ### LR-ASPP

# %%
import torch
from network.lraspp import lraspp_mobilenet_v3_large

from train import args
import loss

# %%
criterion, criterion_val = loss.get_loss(args)
criterion_aux = loss.get_loss_aux(args)
# Out:
# standard cross entropy
# standard cross entropy

# %%
model = lraspp_mobilenet_v3_large(args=args,
                                  criterion=criterion, 
                                  criterion_aux=criterion_aux, 
                                  cont_proj_head=args.cont_proj_head, 
                                  wild_cont_dict_size=args.wild_cont_dict_size)
# Out:
# Loading ImageNet weights...

# %%
with torch.no_grad():
    model.eval()
    o, f = model(torch.zeros(1,3,224,224))

# %%
f['low'].shape, f['high'].shape
# Out:
# (torch.Size([1, 40, 28, 28]), torch.Size([1, 960, 14, 14]))
